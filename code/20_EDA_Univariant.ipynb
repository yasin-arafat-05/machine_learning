# %% [markdown]
# <br>
#
# # Lecture 20: Univariant Analysis:
#
# <br>

# %% [markdown]
# <br>
#
# `Uni` means `Single` <br>
# `Variant` means `Variable` <br>
# ### Univariant Analysis:
# `When we analysis of a single variable that we called Univariant Analysis.` <br>
# ### Bivariant and multi-variant Analysis:
# `In, our data there are multiple columns if we analysis only a single column that what we called Univariant Analysis . If we analysis two column that what we called bivariant analysis. If we analysis multiple column that what we called multi-variant analysis.`
#
# <br>

# %% [markdown]
# # For Understanding EDA:
#
# We need to know about data type.
#
# #### There are two types of data type.
# - `Numerical`
# - `Categorical`

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# our problem is base on the data a passernger will survived or not.

df = sns.load_dataset('titanic')
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 641         1       1  female  24.0      0      0   69.3000        C   First
# 522         0       3    male   NaN      0      0    7.2250        C   Third
# 418         0       2    male  30.0      0      0   13.0000        S  Second
# 679         1       1    male  36.0      0      1  512.3292        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 641  woman       False    B    Cherbourg   yes   True
# 522    man        True  NaN    Cherbourg    no   True
# 418    man        True  NaN  Southampton    no   True
# 679    man        True    B    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True

# %% [markdown]
# <br>
#
# # Step to follow:
#
# - `First, we ask the basic 5 question: in (lecture_19)`
#
# <br>

# %% [markdown]
# **Variable Notes: from kaggle**
#
# **pclass:** A proxy for socio-economic status (SES)
# - 1st = Upper
# - 2nd = Middle
# - 3rd = Lower
#
# **age:** Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp:** The dataset defines family relations in this way...<br>
# Sibling: = brother, sister, stepbrother, stepsister <br>
# Spouse: = husband, wife (mistresses and fiancés were ignored)
#
# **parch:** The dataset defines family relations in this way... <br>
# Parent: = mother, father <br>
# Child = daughter, son, stepdaughter, stepson <br>
# Some children travelled only with a nanny, therefore parch=0 for them.
#
# **embarked:**	Port of Embarkation,C = Cherbourg,Q = Queenstown,S = Southampton
# <br>

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
#
#
# # 1) First we focus on categorical data :
#
# <br>
#
# ## a. Countplot:
#
# ### we can see the count number:
#
# ` Hence, here we can treat the pclass,survived as a categorical data. like sex is a categorical data here either female or male. `
#
# `Name is like categorical but here category is so many . we need  NLP to analysis this.`
#
# <br>

# %%
sns.countplot(x='survived',data=df)

df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='pclass',data=df)
df['pclass'].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='sex',data=df)
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x='embark_town',data=df)
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %% [markdown]
# <br>
#
# # Pie Chart:
#
# <br>
#
# ` Category exactly count the number of category but if we want to show it with percentage then we need piechart. `
#
# <br>

# %%
df['pclass'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['sex'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# <br> <br>
#
# # On Numerical Data:
#
# <br> <br>

# %% [markdown]
# - 1. Histrogram
# - 2. Displot
# - 3. Boxplot

# %% [markdown]
# # 1. Histrogram:

# %%
plt.hist(x='age',data=df,bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# # 2.Displot:

# %%
sns.displot(data=df,x='age',kind='kde') 

# kde (we call it kernel density function) from this graph we can say that if 
# we take a people whose age be 40 the probability is 0.015 .

# %% [markdown]
# # 3. Boxplot:

# %%
sns.boxplot(x='fare',data=df) # outliers onk onk beci
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot(x='age',data=df)
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# <br>
#
# # find the skewness of the graph:
#
#
# <br>

# %%
df['age'].skew() # if this = 0 then the data is normally distrubuted ofthe graph:
                 # if negative then maximum data is in the nevative range "positively skewed"
                 # if positive then maximum data in the posive range: "negatively skewed"
# Out:
# 0.38910778230082704
