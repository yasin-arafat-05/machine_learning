# %% [markdown]
# <br>
#
# # Fetch data from api
#
# <br>

# %% [markdown]
# # TMDB API: (from my account api_Key and api_access_token)
#
# `api_Key :` 740bbd5f4b8d91fc326127c57b7f2ba3
#
# <br>
#
#
# `api_access_token: ` <br>
#
# eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NDBiYmQ1ZjRiOGQ5MWZjMzI2MTI3YzU3YjdmMmJhMyIsIm5iZiI6MTcxOTM5MjMyMC4yNjk5NzQsInN1YiI6IjY2N2JkNjUzNWFiYmM3MmE0MDcyZDllMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.AnuftevmHiHaNhGLdhEYkZj0-e1v87W-xVwFyyKGJVM
#
# <br>

# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NDBiYmQ1ZjRiOGQ5MWZjMzI2MTI3YzU3YjdmMmJhMyIsIm5iZiI6MTcxOTM5MjMyMC4yNjk5NzQsInN1YiI6IjY2N2JkNjUzNWFiYmM3MmE0MDcyZDllMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.AnuftevmHiHaNhGLdhEYkZj0-e1v87W-xVwFyyKGJVM"
}

# Parameters for the API request
params = {
    "language": "en-US",
    "page": 2
}

response = requests.get(url, headers=headers,params=params)

response.json()
# Out:
# {'page': 2,
#  'results': [{'backdrop_path': '/gRApXuxWmO2forYTuTmcz5RaNUV.jpg',
#    'id': 573435,
#    'original_title': 'Bad Boys: Ride or Die',
#    'overview': 'After their late former Captain is framed, Lowrey and Burnett try to clear his name, only to end up on the run themselves.',
#    'poster_path': '/nP6RliHjxsz4irTKsxe8FRhKZYl.jpg',
#    'media_type': 'movie',
#    'adult': False,
#    'title': 'Bad Boys: Ride or Die',
#    'original_language': 'en',
#    'genre_ids': [28, 80, 53, 35],
#    'popularity': 1535.561,
#    'release_date': '2024-06-05',
#    'video': False,
#    'vote_average': 7.013,
#    'vote_count': 434},
#   {'backdrop_path': '/fqv8v6AycXKsivp1T5yKtLbGXce.jpg',
#    'id': 653346,
#    'original_title': 'Kingdom of the Planet of the Apes',
# ...

# %%
response.json()['total_pages']
# Out:
# 1000

# %%
pd.DataFrame(response.json()['results'])
# Out:
#                        backdrop_path       id  \
# 0   /gRApXuxWmO2forYTuTmcz5RaNUV.jpg   573435
# 1   /fqv8v6AycXKsivp1T5yKtLbGXce.jpg   653346
# 2    /H5HjE7Xb9N09rbWn1zBfxgI8uz.jpg   746036
# 3   /s5znBQmprDJJ553IMQfwEVlfroH.jpg   799583
# 4   /g83O8ykeRhsMoHA0LjtOOi8m6ZW.jpg  1143019
# 5   /pPUSCLKQLSUCMVmku7tX4QrjCI8.jpg  1280768
# 6   /z121dSTR7PY9KxKuvwiIFSYW8cf.jpg   929590
# 7   /ao7qIklCUpy2xyNOPci2TWIe5ne.jpg  1215918
# 8   /dYGJ9cI3pUjCUITfxxsO5kEGKTF.jpg  1279433
# 9    /SI22DaQXIfDvLrNBHGpSVShrsC.jpg   829402
# 10  /rQVHRe8uc62FNSi7HVjNhpuKEXR.jpg   937287
# 11  /lA6KdSkCTxwzvqzPqxch997RabQ.jpg   560016
# 12  /zRKQW58MBEY078AxkHxEJzUskCl.jpg   438631
# 13  /w2zsNG7WKBMH35QqcFYILEAdYDU.jpg  1026999
# 14  /2eYiXlynI2mSuYJPUkHupJm2dJp.jpg     9659
# 15  /kYgQzzjNis5jJalYtIHgrom0gOx.jpg  1011985
# 16  /iTWrsOVsUqcwYSxrpINNs3hG2nC.jpg  1001311
# 17  /xTqHr4qhqm6J7vIn6x7GlQArqhk.jpg  1029955
# 18  /fY3lD0jM5AoHJMunjGWqJ0hRteI.jpg   940721
# ...

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#          id                                  title  \
# 0    573435                  Bad Boys: Ride or Die
# 1    653346      Kingdom of the Planet of the Apes
# 2    746036                           The Fall Guy
# 3    799583  The Ministry of Ungentlemanly Warfare
# 4   1143019                        The Infallibles
# 5   1280768     No Time to Spy: A Loud House Movie
# 6    929590                              Civil War
# 7   1215918                        Blackwater Lane
# 8   1279433                            Inheritance
# 9    829402                       Ultraman: Rising
# 10   937287                            Challengers
# 11   560016                             Monkey Man
# 12   438631                                   Dune
# 13  1026999                          Kleks Academy
# 14     9659                                Mad Max
# 15  1011985                        Kung Fu Panda 4
# 16  1001311                            Under Paris
# ...

# %% [markdown]
# ---
#
# <br>
#
# #### `After geeeting the response: go to any json viwer search in google:`
#
# <br>
#
# ---

# %% [markdown]
# # make the data frame for all the movies:

# %%
# create a empty datast:

df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NDBiYmQ1ZjRiOGQ5MWZjMzI2MTI3YzU3YjdmMmJhMyIsIm5iZiI6MTcxOTM5MjMyMC4yNjk5NzQsInN1YiI6IjY2N2JkNjUzNWFiYmM3MmE0MDcyZDllMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.AnuftevmHiHaNhGLdhEYkZj0-e1v87W-xVwFyyKGJVM"
}

# Parameters for the API request
params = {
    "language": "en-US",
    "page": 2
}

response = requests.get(url, headers=headers,params=params)

for i in range(1,1001):
    # Parameters for the API request
    params = {
    "language": "en-US",
    "page": 2
    }
    response = requests.get(url, headers=headers,params=params)
    response_data = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df,response_data],ignore_index = True)

# %%
df
# Out:
#             id                                  title  \
# 0       573435                  Bad Boys: Ride or Die
# 1       653346      Kingdom of the Planet of the Apes
# 2       746036                           The Fall Guy
# 3       799583  The Ministry of Ungentlemanly Warfare
# 4      1143019                        The Infallibles
# ...        ...                                    ...
# 19995  1011985                        Kung Fu Panda 4
# 19996  1001311                            Under Paris
# 19997  1029955                      Kinds of Kindness
# 19998   940721                     Godzilla Minus One
# 19999       11                              Star Wars
#
#                                                 overview release_date  \
# 0      After their late former Captain is framed, Low...   2024-06-05
# 1      Several generations in the future following Ca...   2024-05-08
# 2      Fresh off an almost career-ending accident, st...   2024-04-24
# ...

# %%
df.to_csv('movies.csv')

# %% [markdown]
# <br>
# <br>
#
# ---
#
#
#
# [in_this_link_we_will_find_many_api_link](https://rapidapi.com/hub)
#
# `Website Name: rapidapi.com`
#
#
# ---
#
# <br>
# <br>
