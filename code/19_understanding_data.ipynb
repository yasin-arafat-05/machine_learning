# %% [markdown]
# <br>
#
# # Understand Data:
#
# **EDA: Exploratory Data Analysis**
#
# -  `Ask some basic question`
#
# - `EDA -> Univariate Analysis.`
#
# - `EDA -> Multivariate Analysis.`
#
# - `Using Pandas Profiler.`
#
# <br>

# %% [markdown]
# <br>
#
# ---
#
# # Ask Some Basic Question:
#
# - How big is the data : `df.shape`
#
# - How does the data look like : `df.head()` best `df.sample()`
#
# - What is the data type of columns + memory use : `df.info()`
#
# - Are there are any missing value : `df.isnull().sum()`
#
# - How does the data look like mathematically : `df.describe()`
#
# - Are there any duplicate value : `df.duplicated().sum()`
#
# - How is the correlation between columns
#
# ---
#
# <br>

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# <br>
#
# # Load the dataset:
#
# <br>

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <br>
#
# # 1. How big the data is?
#
# <br>

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <br>
#
# # 2. How does data look likes?
#
# <br>

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 767          768         0       3
# 254          255         0       3
# 81            82         1       3
# 622          623         1       3
# 831          832         1       2
# 794          795         0       3
# 521          522         0       3
# 312          313         0       2
# 506          507         1       2
# 499          500         0       3
#
#                                               Name     Sex    Age  SibSp  \
# 767                             Mangan, Miss. Mary  female  30.50      0
# 254       Rosblom, Mrs. Viktor (Helena Wilhelmina)  female  41.00      0
# 81                     Sheerlinck, Mr. Jan Baptist    male  29.00      0
# 622                               Nakid, Mr. Sahid    male  20.00      1
# 831                Richards, Master. George Sibley    male   0.83      1
# 794                          Dantcheff, Mr. Ristiu    male  25.00      0
# 521                                Vovk, Mr. Janko    male  22.00      0
# 312          Lahtinen, Mrs. William (Anna Sylfven)  female  26.00      1
# 506  Quick, Mrs. Frederick Charles (Jane Richards)  female  33.00      0
# 499                             Svensson, Mr. Olof    male  24.00      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 767      0  364850   7.7500   NaN        Q
# 254      2  370129  20.2125   NaN        S
# 81       0  345779   9.5000   NaN        S
# 622      1    2653  15.7417   NaN        C
# 831      1   29106  18.7500   NaN        S
# 794      0  349203   7.8958   NaN        S
# 521      0  349252   7.8958   NaN        S
# 312      1  250651  26.0000   NaN        S
# 506      2   26360  26.0000   NaN        S
# 499      0  350035   7.7958   NaN        S

# %% [markdown]
# <br>
#
# # What is the data types of each columns
#
#
# <br>

# %%
df.info()


""" 

Optimization trick:

Here age in float64 if we convert it into int then our total memory  will be reduce.

"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ' \n\nOptimization trick:\n\nHere age in float64 if we convert it into int then our total memory  will be reduce.\n\n'

# %% [markdown]
# <br>
#
# # 4. Are there any missing values?
# <br>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <br>
#
# # 5. How does the data look like mathematically
#
# <br>

# %%
df.describe()

# from age we can say that: almost everyone age is (29)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <br>
#
# # 6. Is there any duplicated value?
#
# <br>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <br>
#
# # 7. Co-reletion between columns:
#
# ` যদি কোন column এর ভ্যালু বাড়ে তাহলে অন্য কোন column এর ভ্যালু কমবে নাকি বাড়বে সেইটা  নির্ধারণ করতে পারি । `
#
# <br>

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# corr only for int and float data types:
df_corr = pd.read_csv(url,usecols=["PassengerId","Survived","Pclass","Age","SibSp","Parch","Fare"])
df_corr.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
df_corr.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# <br>
#
# ` Survived এর সাথে বাকী কলাম গুলোর সর্ম্পক । যত বেশি পজিটিভ সর্ম্পক তত বেশি ভালো । Survived এর মান ১ কারণ নিজে নিজের সাথে সর্ম্পক অনেক অনেক বেশি । তারপর, Fare, মানে যে যত বেশি ধনী তারা Survived বেশি হয়েছে । কারণ,তাদের লাইফজ্যাকেট এর ব্যবস্থা ছিল । সব কিছুতে তাদের prority অনেক দেওয়া হয়েছে ।  তেমনি Age এর সাথে Survived এর Co-reletion নাই বলতে চলে ।  `
#
# <br>

# %%
df_corr.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
